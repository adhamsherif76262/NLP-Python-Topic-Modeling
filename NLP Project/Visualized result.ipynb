# %%
pip install pyLDAvis --user
# Out:
# ...
#   Using cached pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
# ...
#   Using cached pandas-2.0.1-cp39-cp39-win_amd64.whl (10.7 MB)
# ...
#   Using cached scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
# ...
#   Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#   Using cached scipy-1.10.1-cp39-cp39-win_amd64.whl (42.5 MB)
# ...
#   Using cached FuzzyTM-2.0.5-py3-none-any.whl (29 kB)
# ...
#   Using cached pyFUME-0.2.25-py3-none-any.whl (67 kB)
# ...
#   Using cached fst_pso-1.8.1-py3-none-any.whl
# ...
#   Using cached simpful-2.10.0-py3-none-any.whl (31 kB)
# ...
#   Using cached miniful-0.0.6-py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle
import pyLDAvis.gensim
import pandas as pd

vis = pd.read_pickle('model_vis.sav')


pyLDAvis.enable_notebook()

vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 12    -0.272688  0.067582       1        1  33.537279
# 1     -0.277611  0.007140       2        1  14.786832
# 14    -0.213342 -0.154740       3        1  10.262183
# 6     -0.259486 -0.158848       4        1  10.114158
# 16    -0.138602  0.008687       5        1   5.639089
# 15    -0.144587  0.175933       6        1   5.615023
# 0     -0.170275  0.153107       7        1   5.471869
# 8     -0.123581 -0.293424       8        1   4.501580
# 10    -0.010019  0.158645       9        1   3.362766
# 2      0.024030  0.094599      10        1   2.012642
# 7      0.123893  0.020997      11        1   1.061572
# 4      0.144320  0.029805      12        1   0.822735
# 17     0.102833  0.129229      13        1   0.787075
# 9      0.217984 -0.047482      14        1   0.458955
# 5      0.268158 -0.047857      15        1   0.407892
# 13     0.235603 -0.026961      16        1   0.405725
# ...
